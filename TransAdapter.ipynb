# %% [markdown]
# <a href="https://colab.research.google.com/github/ssudhanshu488/Vision_Based_UDA/blob/main/TransAdapter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check GPU + CUDA
# !nvidia-smi
# !nvcc --version

# Install PyTorch for CUDA 11.8
# !pip install torch==2.1.1+cu118 torchvision==0.16.1+cu118 torchaudio==2.1.1 --index-url https://download.pytorch.org/whl/cu118

# Core utilities
# !pip install numpy==1.26.4 scipy==1.13.1 scikit-learn==1.5.1 matplotlib==3.9.1.post1 opencv-python==4.10.0.84 tqdm

# Additional tools and model deps
# !pip install timm==1.0.8 wandb grad-cam==1.5.2 ml-collections cupy-cuda11x kmeans-gpu

# Optional: If you need ffmpeg and others
# !apt-get install -y ffmpeg
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 634.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 78.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 8.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
# ...

# %%
# !git clone https://github.com/enesdoruk/TransAdapter
# Out:
# Cloning into 'TransAdapter'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 151 (delta 31), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 2.56 MiB | 8.88 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# !chmod +x /content/TransAdapter/scripts/train_swin.sh

# %%
# !ls
# Out:
# sample_data  TransAdapter

# %%
# %cd TransAdapter/
# Out:
# /content/TransAdapter

# %%
# !chmod +x /content/TransAdapter/scripts/train_swin.sh

# %%
# !/content/TransAdapter/scripts/train_swin.sh
# Out:
# [Warning] Fused window process have not been installed. Please refer to get_started.md for installation.
# wandb: Currently logged in as: ssudhanshu488 (ssudhanshu488-iiit-guwahati) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/TransAdapter/wandb/run-20250526_192247-ygp1gy7h
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transadapter
# wandb: ⭐️ View project at https://wandb.ai/ssudhanshu488-iiit-guwahati/Unsupervised%20Vision%20Transformer
# wandb: 🚀 View run at https://wandb.ai/ssudhanshu488-iiit-guwahati/Unsupervised%20Vision%20Transformer/runs/ygp1gy7h
# [2025-05-26 19:22:48 base__26-05-19](train_swin.py 275): INFO Creating model:base
# [2025-05-26 19:22:50 base__26-05-19](train_swin.py 331): INFO SwinTransformer(
#   (transformer): Swin(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
# ...

# %%
# !wget -P /content/TransAdapter/checkpoints/ https://github.com/microsoft/Swin-Transformer/releases/download/v1.0.0/swin_base_patch4_window7_224_22k.pth
# Out:
# --2025-05-26 19:01:16--  https://github.com/microsoft/Swin-Transformer/releases/download/v1.0.0/swin_base_patch4_window7_224_22k.pth
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-26 19:01:17 ERROR 404: Not Found.

# %%
# !unzip "/content/TransAdapter/data/office/domain adaptation images.zip" -d "/content/TransAdapter/data/office"
# Out:
# Archive:  /content/TransAdapter/data/office/domain adaptation images.zip
#    creating: /content/TransAdapter/data/office/domain adaptation images/
#    creating: /content/TransAdapter/data/office/domain adaptation images/amazon/
#    creating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/
#    creating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/back_pack/
#   inflating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/back_pack/frame_0001.jpg
#   inflating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/back_pack/frame_0002.jpg
#   inflating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/back_pack/frame_0003.jpg
#   inflating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/back_pack/frame_0004.jpg
#   inflating: /content/TransAdapter/data/office/domain adaptation images/amazon/images/back_pack/frame_0005.jpg
# ...

# %%
# !ls
# Out:
# checkpoints  environment.yml  logs	output	   test.py		  utils
# data	     figures	      __MACOSX	README.md  train_swin.py	  wandb
# data.zip     kernels	      models	scripts    train_transadapter.py

# %%
# !ls -l "/content/TransAdapter/data/office/domain_adaptation_images/webcam/images/mug/frame_0023.jpg"
# Out:
# ls: cannot access '/content/TransAdapter/data/office/domain_adaptation_images/webcam/images/mug/frame_0023.jpg': No such file or directory

# %%
# !ls -R /content/TransAdapter/data/office/domain_adaptation_images/
# Out:
# ls: cannot access '/content/TransAdapter/data/office/domain_adaptation_images/': No such file or directory

# %%
import shutil

# Zip the folder "my_folder" into "my_folder.zip"
shutil.make_archive('my_folder', 'zip', '/content/TransAdapter')
